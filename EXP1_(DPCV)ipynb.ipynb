# %%
import cv2
import numpy as np
from matplotlib import pyplot as plt
import pandas as pd

# %%
from google.colab import drive
drive.mount('/content/gdrive')
# Out:
# Mounted at /content/gdrive

# %%
img=cv2.imread('/content/gdrive/MyDrive/neural_style_transfer_images/style_images/style_image.jpg')

# %%
fig,ax=plt.subplots(nrows=2,ncols=1,figsize=(15,10))
hist1=ax[0].hist(img.ravel(),50,[0,256])
img1=ax[1].imshow(img)

# %%
color=('b','g','r')
fig,ax=plt.subplots(nrows=3,ncols=2,figsize=(16,8))
for i,col in enumerate(color):
  histr=cv2.calcHist([img],[i],None,[64],[0,256])
  ax[i,0].plot(histr,color=col)
  #ax[i,0].axis(xmin=0,xmax=256)
img=cv2.imread('/content/gdrive/MyDrive/neural_style_transfer_images/style_images/style_image.jpg')
img2=ax[0,1].imshow(img)

# %%
shade_1=cv2.imread('/content/gdrive/MyDrive/DPCV_images/shade_1.jpg')
shade_2=cv2.imread('/content/gdrive/MyDrive/DPCV_images/shade_2.png')
shade_1_g=cv2.cvtColor(shade_1,cv2.COLOR_BGR2GRAY)
shade_2_g=cv2.cvtColor(shade_2,cv2.COLOR_BGR2GRAY)

# %%
fig,ax=plt.subplots(nrows=2,ncols=2,figsize=(15,10))
hist1=ax[0,0].hist(shade_1.ravel(),16,[0,256])
img1=ax[0,1].imshow(shade_1)
hist2=ax[1,0].hist(shade_2.ravel(),256,[0,256])
img2=ax[1,1].imshow(shade_2)

# %%
fig,ax=plt.subplots(nrows=2,ncols=2,figsize=(15,10))
hist1=ax[0,0].hist(shade_1_g.ravel(),20,[0,256])
img1=ax[0,1].imshow(shade_1)
hist2=ax[1,0].hist(shade_2_g.ravel(),50,[0,256])
img2=ax[1,1].imshow(shade_2)

# %%
color=('b','g','r')
fig,ax=plt.subplots(nrows=1,ncols=2,figsize=(16,8))
for i,col in enumerate(color):
  histr=cv2.calcHist([shade_2],[i],None,[256],[0,256])
  ax[0].plot(histr,color=col)
img2=ax[1].imshow(shade_2)

# %%
im3_t = np.array(shade_1_g)
df = pd.DataFrame(im3_t[4:15,5:20])
df.style.set_properties(**{'font-size':'6pt'}).background_gradient('Greys')
# Out:
# <style  type="text/css" >
# ...
